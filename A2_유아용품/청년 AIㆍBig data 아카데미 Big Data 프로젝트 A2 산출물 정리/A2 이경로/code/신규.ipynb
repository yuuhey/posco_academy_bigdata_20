# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='D2Coding')
plt.rcParams['axes.unicode_minus'] = False
# %matplotlib inline

# %%
df = pd.read_csv('../data/new_sales4.csv', encoding='euc-kr')
df['수량추정'].replace(np.inf, 1, inplace=True)

purch_times = df.groupby('고객번호', as_index=False)['구매금액'].count().rename(columns={'구매금액': '구매회수'})
df = pd.merge(df, purch_times, on='고객번호', how='left')
df
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 2                  201902282095385  2019-02-28  2019-03-01  2019-03-05
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905092356247  2019-05-10  2019-05-11  2019-05-13
# ...                            ...         ...         ...         ...
# 199511  20200521172454-86563196093  2020-05-22  2020-05-23  2020-05-25
# 199512             201912283245128  2019-12-29  2019-12-30  2020-01-01
# 199513             202004103645638  2020-04-10  2020-04-11  2020-04-13
# 199514             201912283245152  2019-12-29  2019-12-30  2020-01-02
# 199515  20200629224818-99047893650  2020-06-30  2020-07-01  2020-07-04
#
#         구매시월령(수정)             고객번호   구매금액   결제금액    물품대분류  \
# 0             4.0  201812310749735  25800  16314     수유용품
# 1            14.0  201812310749735  51200  37769      5단계
# 2             NaN  201812310749770   5610   3800       티슈
# 3            66.0  201812310749771  59520  47922      3단계
# 4             5.0  201812310749774  50640  39788      3단계
# ...           ...              ...    ...    ...      ...
# 199511        3.0  201912281058006   5900   5900      3단계
# 199512        NaN  201912281058007  65880  52065  아이_생활용품
# 199513        3.0  201912281058011   9500   7524      이벤트
# 199514       -3.0  201912281058012   3000   3000      이벤트
# 199515        2.0  201912281058012   5900   5900      이벤트
#
#                                            상품명      수량추정     구매월   할인율  구매회수
# 0                더블하트 SofTouch 모유실감 젖꼭지 M (2입)  2.000000  201905  0.37     2
# 1             NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)  1.155756  202002  0.26     2
# 2                       크리넥스？키즈용？화장지？3겹？27m 8롤  1.000000  201902  0.32     1
# 3               하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)  1.125142  201905  0.19     1
# 4              하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형)  1.000000  201905  0.21     2
# ...                                        ...       ...     ...   ...   ...
# 199511  NEW 하기스 맥스드라이 3단계 공용 20매(밴드형/체험팩) (EA)  1.000000  202005  0.00     2
# 199512    하기스 매직핏 꿀벅지 아기용 기저귀 3단계 공용 198매(밴드형)  1.000000  201912  0.21     1
# 199513                         더블하트 다기능 빨대 브러쉬  1.000000  202004  0.21     1
# 199514                                 맘큐 허그박스  1.000000  201912  0.00     2
# 199515  NEW 하기스 맥스드라이 3단계 공용 20매(밴드형/체험팩) (EA)  1.000000  202006  0.00     2
#
# [199516 rows x 14 columns]

# %%
first_df = df.drop_duplicates(subset='고객번호', keep='first')
first_df['물품대분류'].value_counts(sort=True)
# Out:
# 이벤트        21287
# 수유용품       11160
# 티슈          8909
# 2단계         6386
# 3단계         6360
# 생리대         4310
# 주방용품        3921
# 4단계         3314
# 청결용품        2408
# 아이_생활용품     2301
# 1단계         2166
# 화장품         2050
# 5단계         2010
# 마스크         1932
# 어른_생활용품     1353
# 6단계          607
# 장난감          283
# 음식           246
# 7단계           34
# 기타            18
# Name: 물품대분류, dtype: int64

# %%
first_df = df.drop_duplicates(subset='고객번호', keep='first')
momq = first_df['상품명'].apply(lambda x: '맘큐' in x)
momq
# Out:
# 0         False
# 2         False
# 3         False
# 4         False
# 6         False
#           ...
# 199509    False
# 199510     True
# 199512    False
# 199513    False
# 199514     True
# Name: 상품명, Length: 81055, dtype: bool
