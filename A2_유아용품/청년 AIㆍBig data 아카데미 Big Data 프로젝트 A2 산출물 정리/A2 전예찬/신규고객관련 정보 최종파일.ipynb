# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
#폰트 설정 
matplotlib.rc("font", family = "Malgun Gothic")
matplotlib.rc("axes", unicode_minus = False)

# %%
df = pd.read_csv('../Downloads/new_sales4.csv', encoding='euc-kr')
df = df[~df['구매시월령(수정)'].isna()]
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [114], line 1
# ----> 1 df = pd.read_csv('../Downloads/new_sales4.csv', encoding='euc-kr')
#       2 df = df[~df['구매시월령(수정)'].isna()]
#       3 df
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
df['구매월'] = df['구매월'].astype(str)
df['구매월'] = df['구매월'].apply(lambda x: f'{x[:4]}-{x[4:]}')
df['구매월'] = pd.to_datetime(df['구매월'])
df
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905092356247  2019-05-10  2019-05-11  2019-05-13
# 5                  201907282649358  2019-07-29  2019-07-30  2019-08-02
# ...                            ...         ...         ...         ...
# 199510             201912283245106  2019-12-29  2019-12-30  2020-01-01
# 199511  20200521172454-86563196093  2020-05-22  2020-05-23  2020-05-25
# 199513             202004103645638  2020-04-10  2020-04-11  2020-04-13
# 199514             201912283245152  2019-12-29  2019-12-30  2020-01-02
# 199515  20200629224818-99047893650  2020-06-30  2020-07-01  2020-07-04
#
#         구매시월령(수정)             고객번호    구매금액   결제금액 물품대분류  \
# 0             4.0  201812310749735   25800  16314  수유용품
# ...

# %%
df2 = pd.read_csv('../Downloads/이탈율.csv', encoding='euc-kr')
df2['가입월'] = df4.values
df2
# Out:
#          월  전체결제수  이용고객수  신규고객수  재구매고객수  복귀고객수    신규_구매금액     재_구매금액  \
# 0   201901   4359   3264   3264       0      0  129393220          0
# 1   201902   7156   5722   5342     380      0  178244750   15373560
# 2   201903   9579   7746   6674    1072      0  192509390   34270050
# 3   201904   8922   7067   5226    1805     36  185576000   65315090
# 4   201905   8949   6826   4765    1862    199  208214560   83075750
# 5   201906  10907   8891   6326    2183    382  194899700  104857400
# 6   201907  14587  11835   7765    2902   1168  235918200  135679190
# 7   201908  12607  10011   6171    3118    722  188658060  158773290
# 8   201909  12829   9995   5564    3581    850  169080720  169798780
# 9   201910  19133  15200   8826    4447   1927  258416950  220573340
# 10  201911  10474   8279   3931    3391    957  127560260  187690850
# 11  201912  17918  14443   7615    4643   2185  209219380  229173770
# 12  202001  11921   8696   2358    4624   1714  103919050  268994650
# ...

# %%
df3 = pd.read_csv("../Desktop/A2_유아용품/멤버데이터가입일월추가.csv", encoding= 'euc-kr')
df3['가입일자'] = df3['가입일자'].apply(lambda x: f'{str(x)[:6]}')
df3 = df3.drop('Unnamed: 0', axis=1)
df3['가입일자'].value_counts()
df3 =df3[99:]
df3.reset_index(inplace=True,drop=True)
df3
# Out:
#                   고객번호 성별 결혼유무 거주지역    연령 결제등록카드    유입경로 자녀여부    가입일자  가입월
# 0      201901010750434  여   기혼   강원  31.0   롯데카드  네이버블로그  Yes  201901  01월
# 1      201901010750428  여   기혼   대전  32.0   국민은행  네이버블로그  Yes  201901  01월
# 2      201901010750425  여   기혼   경기  34.0   국민은행  네이버블로그  Yes  201901  01월
# 3      201901010750418  여   기혼   대전  32.0   국민은행  네이버블로그  Yes  201901  01월
# 4      201901010750401  여   기혼   서울  34.0   국민카드  네이버블로그  Yes  201901  01월
# ...                ... ..  ...  ...   ...    ...     ...  ...     ...  ...
# 80990  201912291058061  여   기혼   대구  32.0   국민은행  네이버블로그  Yes  201912  12월
# 80991  201912291058064  여   기혼   경기  33.0   롯데카드    지인추천  Yes  201912  12월
# 80992  201912291058070  여   미혼   대전  31.0  농협중앙회   인스타그램   No  201912  12월
# 80993  201912291058094  여   미혼   인천  31.0  농협중앙회  네이버블로그   No  201912  12월
# 80994  201912291058171  여   기혼   서울  35.0  새마을금고   인스타그램  Yes  201912  12월
#
# [80995 rows x 10 columns]

# %%
df4 = df3['가입일자'].value_counts()
df4['202001']=0
df4['202002']=0
df4['202003']=0
df4['202004']=0
df4['202005']=0
df4['202006']=0
df4['202007']=0
df4['202008']=0

df4 = df4.sort_index()

# %%
df3['가입일자'] = df3['가입일자'].apply(lambda x: f'{str(x)[:6]}')
# df3 = df3.drop('Unnamed: 0', axis=1)
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 2                  201902282095385  2019-02-28  2019-03-01  2019-03-05
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905092356247  2019-05-10  2019-05-11  2019-05-13
# ...                            ...         ...         ...         ...
# 199994  20200724113704-52679491210  2020-07-24  2020-07-25  2020-07-27
# 199995  20200729134816-18220910068  2020-07-29  2020-07-30  2020-08-01
# 199996  20200803080150-09054399128  2020-08-03  2020-08-04  2020-08-07
# 199997  20200805171023-18783441109  2020-08-06  2020-08-07  2020-08-11
# 199998  20200805224157-34181488371  2020-08-06  2020-08-07  2020-08-09
#
#         구매시월령(수정)                  고객번호   구매금액   결제금액 물품대분류  \
# ...

# %%
df2['월'] = df2['월'].astype(str)
df2['월'] = df2['월'].apply(lambda x: f'{x[:4]}-{x[4:]}')
df2['월'] = pd.to_datetime(df2['월'])
df2
# Out:
#             월  전체결제수  이용고객수  신규고객수  재구매고객수  복귀고객수    신규_구매금액     재_구매금액  \
# 0  2019-01-01   4359   3264   3264       0      0  129393220          0
# 1  2019-02-01   7156   5722   5342     380      0  178244750   15373560
# 2  2019-03-01   9579   7746   6674    1072      0  192509390   34270050
# 3  2019-04-01   8922   7067   5226    1805     36  185576000   65315090
# 4  2019-05-01   8949   6826   4765    1862    199  208214560   83075750
# 5  2019-06-01  10907   8891   6326    2183    382  194899700  104857400
# 6  2019-07-01  14587  11835   7765    2902   1168  235918200  135679190
# 7  2019-08-01  12607  10011   6171    3118    722  188658060  158773290
# 8  2019-09-01  12829   9995   5564    3581    850  169080720  169798780
# 9  2019-10-01  19133  15200   8826    4447   1927  258416950  220573340
# 10 2019-11-01  10474   8279   3931    3391    957  127560260  187690850
# 11 2019-12-01  17918  14443   7615    4643   2185  209219380  229173770
# ...

# %%
df5 = df2[0:12]
df5
# Out:
#             월  전체결제수  이용고객수  신규고객수  재구매고객수  복귀고객수    신규_구매금액     재_구매금액  \
# 0  2019-01-01   4359   3264   3264       0      0  129393220          0
# 1  2019-02-01   7156   5722   5342     380      0  178244750   15373560
# 2  2019-03-01   9579   7746   6674    1072      0  192509390   34270050
# 3  2019-04-01   8922   7067   5226    1805     36  185576000   65315090
# 4  2019-05-01   8949   6826   4765    1862    199  208214560   83075750
# 5  2019-06-01  10907   8891   6326    2183    382  194899700  104857400
# 6  2019-07-01  14587  11835   7765    2902   1168  235918200  135679190
# 7  2019-08-01  12607  10011   6171    3118    722  188658060  158773290
# 8  2019-09-01  12829   9995   5564    3581    850  169080720  169798780
# 9  2019-10-01  19133  15200   8826    4447   1927  258416950  220573340
# 10 2019-11-01  10474   8279   3931    3391    957  127560260  187690850
# 11 2019-12-01  17918  14443   7615    4643   2185  209219380  229173770
#
# ...

# %%
df5['신규구매금액누적']=df5['신규_구매금액'].cumsum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25044\2890652983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['신규구매금액누적']=df5['신규_구매금액'].cumsum()

# %%
df5['신규_구매금액'].sum()/df5['신규가입수'].sum()
# Out:
# 28121.380208654857

# %%
(28121.380208654857*12000+df5['전체매출'].sum())/df5['전체매출'].sum()
# Out:
# 1.0916435664384736

# %%
df5['가입대비구매']=df5['']/df5['가입누적']
df5['이탈율']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25044\2737554058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['가입대비구매']=df5['신규고객누적']/df5['가입누적']
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.446998
# 4     0.674589
# 5     0.718177
# 6     0.589359
# 7     0.543217
# 8     0.597233
# 9     0.624250
# 10    0.661273
# 11    0.535468
# Name: 이탈율, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
df5['신규가입수']
# Out:
# 0     10809
# 1      9463
# 2      9719
# 3      5643
# 4      5668
# 5      6271
# 6      5847
# 7      5786
# 8      4898
# 9      7705
# 10     3556
# 11     5630
# Name: 신규가입수, dtype: int64

# %%
df5['신규가입수'].stan

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data= df5.corr(),annot= True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25044\1842578566.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data= df5.corr(),annot= True)
# <AxesSubplot: >

# %%
sns.barplot(data=df5, x='월', y='신규고객수',color = 'blue',)
sns.barplot(data=df5, x='월', y='가입월', color = 'red')
ax2 = plt.twinx()

sns.barplot(data=df5, x='월', y='전체매출', ax=ax2,color = 'green')
# Out:
# <AxesSubplot: xlabel='월', ylabel='전체매출'>

# %%
df5.rename(columns={'가입월':'신규가입수'},inplace = True)
df5['']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25044\177394338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.rename(columns={'가입월':'신규가입수'},inplace = True)
#             월  전체결제수  이용고객수  신규고객수  재구매고객수  복귀고객수    신규_구매금액     재_구매금액  \
# 0  2019-01-01   4359   3264   3264       0      0  129393220          0
# 1  2019-02-01   7156   5722   5342     380      0  178244750   15373560
# 2  2019-03-01   9579   7746   6674    1072      0  192509390   34270050
# 3  2019-04-01   8922   7067   5226    1805     36  185576000   65315090
# 4  2019-05-01   8949   6826   4765    1862    199  208214560   83075750
# 5  2019-06-01  10907   8891   6326    2183    382  194899700  104857400
# 6  2019-07-01  14587  11835   7765    2902   1168  235918200  135679190
# ...

# %%
df5['신규_구매금액']
# Out:
# 0     129393220
# 1     178244750
# 2     192509390
# 3     185576000
# 4     208214560
# 5     194899700
# 6     235918200
# 7     188658060
# 8     169080720
# 9     258416950
# 10    127560260
# 11    209219380
# Name: 신규_구매금액, dtype: int64

# %%
plt.figure(figsize=(40,10))
sns.lineplot(data=df5, x='월', y='신규_구매금액',color = 'blue')



sns.lineplot(data=df5, x='월', y='전체매출',color = 'red')
plt.savefig('첫구매할인율대비신규가입수.png')

# %%
sns.barplot(data=df5, x='월', y='전체매출',color = 'blue')
# Out:
# <AxesSubplot: xlabel='월', ylabel='전체매출'>

# %%
df5
# Out:
#             월  전체결제수  이용고객수  신규고객수  재구매고객수  복귀고객수    신규_구매금액     재_구매금액  \
# 0  2019-01-01   4359   3264   3264       0      0  129393220          0
# 1  2019-02-01   7156   5722   5342     380      0  178244750   15373560
# 2  2019-03-01   9579   7746   6674    1072      0  192509390   34270050
# 3  2019-04-01   8922   7067   5226    1805     36  185576000   65315090
# 4  2019-05-01   8949   6826   4765    1862    199  208214560   83075750
# 5  2019-06-01  10907   8891   6326    2183    382  194899700  104857400
# 6  2019-07-01  14587  11835   7765    2902   1168  235918200  135679190
# 7  2019-08-01  12607  10011   6171    3118    722  188658060  158773290
# 8  2019-09-01  12829   9995   5564    3581    850  169080720  169798780
# 9  2019-10-01  19133  15200   8826    4447   1927  258416950  220573340
# 10 2019-11-01  10474   8279   3931    3391    957  127560260  187690850
# 11 2019-12-01  17918  14443   7615    4643   2185  209219380  229173770
#
# ...

# %%
df_grouped
# Out:
#           구매월       할인율    구매량
# 0  2019-01-01  0.306390   3834
# 1  2019-02-01  0.264299   5317
# 2  2019-03-01  0.267269   6705
# 3  2019-04-01  0.273887   6907
# 4  2019-05-01  0.272070   7950
# 5  2019-06-01  0.215150   9519
# 6  2019-07-01  0.239419  12418
# 7  2019-08-01  0.208093  10905
# 8  2019-09-01  0.213846  11173
# 9  2019-10-01  0.238462  16226
# 10 2019-11-01  0.225121   9144
# 11 2019-12-01  0.254415  14070
# 12 2020-01-01  0.290342  10273
# 13 2020-02-01  0.225907  10111
# 14 2020-03-01  0.201935   8410
# 15 2020-04-01  0.224663   7328
# 16 2020-05-01  0.251607   5912
# 17 2020-06-01  0.240005   4277
# 18 2020-07-01  0.245648   6171
# 19 2020-08-01  0.253876   1136

# %%
df_grouped = df.groupby('구매월', as_index=False)['할인율'].mean()
df_grouped['구매량'] = df.groupby('구매월')['주문번호'].count().values
sns.lineplot(data=df_grouped, x='구매월', y='할인율')
sns.lineplot(data=df_grouped, x='구매월', y='구매량')

# plt.xticks(df_grouped['구매월'])
# Out:
# <AxesSubplot: xlabel='구매월', ylabel='할인율'>

# %%
sns.lineplot(data=df_grouped, x='구매월', y='구매량')
# Out:
# <AxesSubplot: xlabel='구매월', ylabel='구매량'>

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(data=df_grouped, x='구매일', y='할인율')
plt.xticks(df_grouped['구매일'][::14].values, rotation=90)

ax2 = plt.twinx()
sns.lineplot(data=df_grouped, x='구매일', y='구매량', ax=ax2, color='red')

plt.legend(['할인율', '구매량'])
plt.show()
# Out:
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# ...

# %%
df_grouped = df.groupby('구매일', as_index=False)['구매금액', '결제금액'].sum()
df_grouped['할인율'] = 1 - (df_grouped['결제금액'] / df_grouped['구매금액'])
df_grouped['구매량'] = df.groupby('구매일')['주문번호'].count().values
df_grouped
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_27608\3851729368.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_grouped = df.groupby('구매일', as_index=False)['구매금액', '결제금액'].sum()
#             구매일     구매금액     결제금액       할인율  구매량
# 0    2019-01-01  1795510  1245706  0.306210   47
# 1    2019-01-02  1566280  1072710  0.315122   45
# 2    2019-01-03  2015440  1350052  0.330145   65
# 3    2019-01-04  1381410  1023317  0.259223   41
# 4    2019-01-05  2017650  1383772  0.314166   57
# ..          ...      ...      ...       ...  ...
# 576  2020-08-03  5890780  3850228  0.346398  180
# 577  2020-08-04  5958840  3785050  0.364801  174
# 578  2020-08-05  6157420  3911836  0.364696  171
# 579  2020-08-06  4976610  3101736  0.376737  163
# 580  2020-08-07  2714100  1619042  0.403470   83
#
# [581 rows x 5 columns]

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(data=df_grouped, x='구매일', y='할인율')
plt.xticks(df_grouped['구매일'][::14].values, rotation=90)

ax2 = plt.twinx()
sns.lineplot(data=df_grouped, x='구매일', y='구매량', ax=ax2, color='red')

plt.legend(['할인율', '구매량'])
plt.show()
# Out:
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# ...

# %% [markdown]
# # 가입일자

# %%
df['가입일자'] = df['고객번호'].apply(lambda x: str(x)[:8])
df
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905092356247  2019-05-10  2019-05-11  2019-05-13
# 5                  201907282649358  2019-07-29  2019-07-30  2019-08-02
# ...                            ...         ...         ...         ...
# 199510             201912283245106  2019-12-29  2019-12-30  2020-01-01
# 199511  20200521172454-86563196093  2020-05-22  2020-05-23  2020-05-25
# 199513             202004103645638  2020-04-10  2020-04-11  2020-04-13
# 199514             201912283245152  2019-12-29  2019-12-30  2020-01-02
# 199515  20200629224818-99047893650  2020-06-30  2020-07-01  2020-07-04
#
#         구매시월령(수정)             고객번호    구매금액   결제금액 물품대분류  \
# 0             4.0  201812310749735   25800  16314  수유용품
# ...

# %%
# 이벤트 판매량
df_grouped = df[df['물품대분류'] == '이벤트'].groupby('가입일자').count().iloc[:,0].reset_index()

plt.figure(figsize=(15, 5))
sns.lineplot(data=df_grouped, x='가입일자', y='주문번호')
plt.xticks(df_grouped['가입일자'][::14].values, rotation=90)

# 신규유입량
df_grouped = df.groupby('구매일', as_index=False)['물품대분류'].count()
ax2 = plt.twinx()
sns.lineplot(data=df_grouped, x='구매일', y='물품대분류', ax=ax2, color='red')

plt.show()

# %%
df = pd.read_csv('../Downloads/new_sales4.csv', encoding='euc-kr')
df = df[df['상품명'] != '맘큐 허그박스']
df = df.drop_duplicates(subset='고객번호', keep='first')
df['구매월'] = pd.to_datetime(df['구매일']).dt.to_period('M')
grouped = df.groupby('구매월', as_index=False)['할인율'].mean()

grouped.plot()
# sns.lineplot(data=grouped, x='구매월', y='할인율')
# Out:
# <AxesSubplot: >

# %%
grouped
# Out:
#         구매월       할인율
# 0   2019-01  0.313312
# 1   2019-02  0.278660
# 2   2019-03  0.275686
# 3   2019-04  0.279977
# 4   2019-05  0.278571
# 5   2019-06  0.268340
# 6   2019-07  0.275264
# 7   2019-08  0.258705
# 8   2019-09  0.249207
# 9   2019-10  0.283464
# 10  2019-11  0.268542
# 11  2019-12  0.289166
# 12  2020-01  0.280845
# 13  2020-02  0.200250
# 14  2020-03  0.171243
# 15  2020-04  0.169254
# 16  2020-05  0.180056
# 17  2020-06  0.149915
# 18  2020-07  0.135839
# 19  2020-08  0.156131

# %%
df5['첫구매할인율'] =grouped['할인율'][0:12]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25044\2487397474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['첫구매할인율'] =grouped['할인율'][0:12]

# %%
df5
# Out:
#             월  전체결제수  이용고객수  신규고객수  재구매고객수  복귀고객수    신규_구매금액     재_구매금액  \
# 0  2019-01-01   4359   3264   3264       0      0  129393220          0
# 1  2019-02-01   7156   5722   5342     380      0  178244750   15373560
# 2  2019-03-01   9579   7746   6674    1072      0  192509390   34270050
# 3  2019-04-01   8922   7067   5226    1805     36  185576000   65315090
# 4  2019-05-01   8949   6826   4765    1862    199  208214560   83075750
# 5  2019-06-01  10907   8891   6326    2183    382  194899700  104857400
# 6  2019-07-01  14587  11835   7765    2902   1168  235918200  135679190
# 7  2019-08-01  12607  10011   6171    3118    722  188658060  158773290
# 8  2019-09-01  12829   9995   5564    3581    850  169080720  169798780
# 9  2019-10-01  19133  15200   8826    4447   1927  258416950  220573340
# 10 2019-11-01  10474   8279   3931    3391    957  127560260  187690850
# 11 2019-12-01  17918  14443   7615    4643   2185  209219380  229173770
#
# ...

# %%
df5.to_csv("신규고객관련파생변수.csv")
