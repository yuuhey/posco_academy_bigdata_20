# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

#폰트 설정 
matplotlib.rc("font", family = "Malgun Gothic")
matplotlib.rc("axes", unicode_minus = False)

# %%
df = pd.read_csv("C:/Users/user/Desktop/A2_유아용품/Member_data.csv")
df = df.dropna()
df=df.sort_values('거주지역')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\3638553750.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/user/Desktop/A2_유아용품/Member_data.csv")

# %%
df['유입경로'].hist()
# Out:
# <AxesSubplot: >

# %%
df.hist('거주지역','유입경로',bins= 15,figsize=(20,40))
plt.savefig('개슈발지역유입그래프.png')

# %%
df= df.sort_values('연령')
df.hist('연령','유입경로',bins= 18,figsize=(20,40))
plt.savefig('연령유입그래프.png')

# %% [markdown]
# 스택 그래프 그리기 실패

# %%
from queue import Queue

# %%
q = Queue() # 빈큐 생성
q.put(1) # add(원소)
q.put(2)
q.put(3)
q.put(4)
q.put(5)
q.get() # 4
# Out:
# 1

# %%
df.hist(column='연령',by= '유입경로')
# Out:
# array([[<AxesSubplot: title={'center': '검색광고'}>,
#         <AxesSubplot: title={'center': '네이버블로그'}>,
#         <AxesSubplot: title={'center': '네이버카페'}>],
#        [<AxesSubplot: title={'center': '매장쿠폰'}>,
#         <AxesSubplot: title={'center': '오픈마켓'}>,
#         <AxesSubplot: title={'center': '이마트'}>],
#        [<AxesSubplot: title={'center': '인스타그램'}>,
#         <AxesSubplot: title={'center': '지인추천'}>,
#         <AxesSubplot: title={'center': '직접검색'}>],
#        [<AxesSubplot: title={'center': '페이스북'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %%
for i in range(len(df)):
    if df['유입경로'][i]=="네이버카페":
        df['유입경로'][i] = '기타(인터넷)'
    if df['유입경로'][i]=="페이스북":
        df['유입경로'][i] = '기타(인터넷)'
    if df['유입경로'][i]=="직접검색":
        df['유입경로'][i] = '기타(인터넷)'
    if df['유입경로'][i]=="오픈마켓":
        df['유입경로'][i] = '기타(인터넷)'
    if df['유입경로'][i]=="매장쿠폰":
        df['유입경로'][i] = '기타(인터넷)'
    if df['유입경로'][i]=="이마트":
        df['유입경로'][i] = '기타(인터넷)'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\2797572743.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['유입경로'][i] = '기타(인터넷)'
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\2797572743.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['유입경로'][i] = '기타(인터넷)'
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\2797572743.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['유입경로'][i] = '기타(인터넷)'
# ...

# %%
df['유입경로'].value_counts()
# Out:
# 인스타그램      31167
# 네이버블로그     22684
# 기타(인터넷)    10963
# 검색광고        8259
# 지인추천        8021
# Name: 유입경로, dtype: int64

# %%
df2 = pd.read_csv('../Downloads/new_sales4.csv',encoding='euc-kr')
df2
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 2                  201902282095385  2019-02-28  2019-03-01  2019-03-05
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905092356247  2019-05-10  2019-05-11  2019-05-13
# ...                            ...         ...         ...         ...
# 199511  20200521172454-86563196093  2020-05-22  2020-05-23  2020-05-25
# 199512             201912283245128  2019-12-29  2019-12-30  2020-01-01
# 199513             202004103645638  2020-04-10  2020-04-11  2020-04-13
# 199514             201912283245152  2019-12-29  2019-12-30  2020-01-02
# 199515  20200629224818-99047893650  2020-06-30  2020-07-01  2020-07-04
#
#         구매시월령(수정)             고객번호   구매금액   결제금액    물품대분류  \
# ...

# %%
df2 = pd.merge(df,df2,on='고객번호',how='right')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\1925056082.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   df2 = pd.merge(df,df2,on='고객번호',how='right')

# %%
type(df2['고객번호'][0])
# Out:
# float

# %%
df2['가입일자'] = 0

for i in range(len(df2)):
    df2['가입일자'][i] = int(str(df2['고객번호'][i])[0:8])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\755945494.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['가입일자'][i] = int(str(df2['고객번호'][i])[0:8])

# %%
df2.merge('가입일자').count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [68], line 1
# ----> 1 df2.merge('가입일자').count()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10080, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10061 @Substitution("")
#   10062 @Appender(_merge_doc, indents=2)
#   10063 def merge(
#    (...)
#   10076     validate: str | None = None,
#   10077 ) -> DataFrame:
#   10078     from pandas.core.reshape.merge import merge
# > 10080     return merge(
#   10081         self,
#   10082         right,
#   10083         how=how,
#   10084         on=on,
#   10085         left_on=left_on,
#   10086         right_on=right_on,
#   10087         left_index=left_index,
#   10088         right_index=right_index,
#   10089         sort=sort,
# ...

# %%
df3 = df3[df3['가입일자']<20190201]
df3
# Out:
#                     고객번호 성별 결혼유무 거주지역    연령  결제등록카드   유입경로 자녀여부  \
# 24068  201901290778210.0  여   기혼   제주  36.0    롯데카드  인스타그램  Yes
# 24069  201901290778210.0  여   기혼   제주  36.0    롯데카드  인스타그램  Yes
# 24070  201901290778211.0  여   기혼   경기  35.0    롯데카드  인스타그램  Yes
# 24071  201901290778212.0  여   기혼   부산  31.0    국민카드  인스타그램  Yes
# 24072  201901290778215.0  여   기혼   서울  35.0    신한은행  인스타그램  Yes
# ...                  ... ..  ...  ...   ...     ...    ...  ...
# 30035  201901310785182.0  여   기혼   충남  31.0    신한은행   지인추천  Yes
# 30036  201901310785185.0  여   기혼   부산  27.0  농협회원조합   검색광고  Yes
# 30037  201901310785185.0  여   기혼   부산  27.0  농협회원조합   검색광고  Yes
# 30038  201901310785200.0  여   기혼   강원  34.0    국민은행  인스타그램  Yes
# 30039  201901310785200.0  여   기혼   강원  34.0    국민은행  인스타그램  Yes
#
#                              주문번호         구매일  ...       배송완료일 구매시월령(수정)  \
# 24068             201902132025623  2019-02-14  ...  2019-02-18       7.0
# ...

# %%
df_maea = df3.groupby('유입경로').mean()
df_count = df3.groupby('유입경로').count()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\2354866591.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_maea = df3.groupby('유입경로').mean()

# %%
df_count
# Out:
#          고객번호    성별  결혼유무  거주지역    연령  결제등록카드  자녀여부  주문번호   구매일  배송시작일  배송완료일  \
# 유입경로
# 검색광고      659   659   659   659   659     659   659   659   659    659    659
# 기타(인터넷)   827   827   827   827   827     827   827   827   827    827    827
# 네이버블로그   1650  1650  1650  1650  1650    1650  1650  1650  1650   1650   1650
# 인스타그램    2218  2218  2218  2218  2218    2218  2218  2218  2218   2218   2218
# 지인추천      618   618   618   618   618     618   618   618   618    618    618
#
#          구매시월령(수정)  구매금액  결제금액  물품대분류   상품명  수량추정   구매월   할인율  가입일자
# 유입경로
# 검색광고           570   659   659    659   659   656   659   656   659
# 기타(인터넷)        760   827   827    827   827   824   827   824   827
# 네이버블로그        1466  1650  1650   1650  1650  1643  1650  1643  1650
# 인스타그램         2010  2218  2218   2218  2218  2210  2218  2210  2218
# 지인추천           574   618   618    618   618   614   618   614   618

# %%
df_maea
# Out:
#                 연령  구매시월령(수정)          구매금액          결제금액  수량추정  \
# 유입경로
# 검색광고     32.922610  20.217544  22775.918058  15978.867982   NaN
# 기타(인터넷)  32.119710  20.072368  28300.604595  19900.154776   NaN
# 네이버블로그   32.641212  17.963847  27289.266667  19189.744848   NaN
# 인스타그램    32.922453  23.033333  26480.933273  18869.124887   NaN
# 지인추천     32.147249  17.022648  30561.974110  21395.323625   NaN
#
#                    구매월       할인율          가입일자
# 유입경로
# 검색광고     201922.464340  0.263537  2.019013e+07
# 기타(인터넷)  201920.831923  0.273896  2.019013e+07
# 네이버블로그   201918.412727  0.274060  2.019013e+07
# 인스타그램    201918.445446  0.266032  2.019013e+07
# 지인추천     201924.778317  0.282769  2.019013e+07

# %%
df6 = df3.groupby('유입경로').sum()
df6['전체매출대비_비율'] = 0
for i in range(len(df6)):
    df6['전체매출대비_비율'][i] = df6['구매금액'][i]/df6['구매금액'].sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\1796566716.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df6 = df3.groupby('유입경로').sum()
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\1796566716.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['전체매출대비_비율'][i] = df6['구매금액'][i]/df6['구매금액'].sum()

# %%
df6
# Out:
#               연령  구매시월령(수정)      구매금액      결제금액  수량추정        구매월     할인율  \
# 유입경로
# 검색광고     21696.0    11524.0  15009330  10530074   NaN  133066904  172.88
# 기타(인터넷)  26563.0    15255.0  23404600  16457428   NaN  166988528  225.69
# 네이버블로그   53858.0    26335.0  45027290  31663079   NaN  333165381  450.28
# 인스타그램    73022.0    46297.0  58734710  41851719   NaN  447855112  587.93
# 지인추천     19867.0     9771.0  18887300  13222310   NaN  124789513  173.62
#
#                 가입일자  전체매출대비_비율
# 유입경로
# 검색광고     13305295784   0.093189
# 기타(인터넷)  16697237561   0.145313
# 네이버블로그   33313714579   0.279563
# 인스타그램    44781708454   0.364669
# 지인추천     12477500390   0.117266

# %%
df2['가입일자'] = 0
for i in range(len(df2)):
    df2['가입일자'][i] = int(str(df2['고객번호'][i])[0:8])
df2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1600\3138024273.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['가입일자'][i] = int(str(df2['고객번호'][i])[0:8])
#                      고객번호   성별 결혼유무 거주지역    연령 결제등록카드    유입경로 자녀여부  \
# 0       201812310749735.0    여   기혼   인천  37.0   국민은행   인스타그램  Yes
# 1       201812310749735.0    여   기혼   인천  37.0   국민은행   인스타그램  Yes
# 2       201812310749770.0    여   기혼   제주  33.0   국민은행    검색광고  Yes
# 3       201812310749771.0    여   기혼   부산  32.0   하나은행  네이버블로그  Yes
# 4       201812310749774.0    여   미혼   경남  34.0   기업은행    지인추천   No
# ...                   ...  ...  ...  ...   ...    ...     ...  ...
# 199511  201912281058006.0  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# 199512  201912281058007.0  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# ...

# %%
df2=df2[df2['']]
# Out:
#                      고객번호   성별 결혼유무 거주지역  연령 결제등록카드 유입경로 자녀여부  \
# 199496  201912281057976.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199497  201912281057976.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199498  201912281057979.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199499  201912281057980.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199500  201912281057984.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199501  201912281057984.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199502  201912281057987.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199503  201912281057991.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199504  201912281057991.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199505  201912281057997.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199506  201912281057997.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199507  201912281057997.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199508  201912281057999.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# 199509  201912281058004.0  NaN  NaN  NaN NaN    NaN  NaN  NaN
# ...
