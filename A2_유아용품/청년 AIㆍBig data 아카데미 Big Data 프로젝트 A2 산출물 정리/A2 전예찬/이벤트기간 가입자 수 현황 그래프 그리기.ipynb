# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

#폰트 설정 
matplotlib.rc("font", family = "Malgun Gothic")
matplotlib.rc("axes", unicode_minus = False)

# %%
df = pd.read_csv("C:/Users/user/Downloads/new_sales4.csv", encoding='euc-kr')
df
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 2                  201902282095385  2019-02-28  2019-03-01  2019-03-05
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905092356247  2019-05-10  2019-05-11  2019-05-13
# ...                            ...         ...         ...         ...
# 199511  20200521172454-86563196093  2020-05-22  2020-05-23  2020-05-25
# 199512             201912283245128  2019-12-29  2019-12-30  2020-01-01
# 199513             202004103645638  2020-04-10  2020-04-11  2020-04-13
# 199514             201912283245152  2019-12-29  2019-12-30  2020-01-02
# 199515  20200629224818-99047893650  2020-06-30  2020-07-01  2020-07-04
#
#         구매시월령(수정)             고객번호   구매금액   결제금액    물품대분류  \
# ...

# %%
df['가입일자']= 0
for i in range(len(df)):
    df['가입일자'][i] = int(str(df['고객번호'][i])[0:8])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24516\2704315534.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['가입일자'][i] = int(str(df['고객번호'][i])[0:8])

# %%
df2 = df[df['가입일자']>20190128]
df2 = df2[df2['가입일자']<20190202]
df2
# Out:
#                   주문번호         구매일       배송시작일       배송완료일  구매시월령(수정)  \
# 24068  201902132025623  2019-02-14  2019-02-15  2019-02-18        7.0
# 24069  201903312215499  2019-03-31  2019-04-01  2019-04-04        8.0
# 24070  201904062245157  2019-04-06  2019-04-07  2019-04-09       58.0
# 24071  201904232307866  2019-04-23  2019-04-24  2019-04-27       -8.0
# 24072  201907282648108  2019-07-28  2019-07-29  2019-07-31        3.0
# ...                ...         ...         ...         ...        ...
# 32344  201903192171369  2019-03-19  2019-03-20  2019-03-22        NaN
# 32345  201902122018701  2019-02-12  2019-02-13  2019-02-16       33.0
# 32346  201912183191320  2019-12-18  2019-12-19  2019-12-21        NaN
# 32347  201903212178437  2019-03-21  2019-03-22  2019-03-25        NaN
# 32348  201904222305457  2019-04-23  2019-04-24  2019-04-26        NaN
#
#                   고객번호   구매금액   결제금액 물품대분류  \
# 24068  201901290778210   6040   3861   이벤트
# ...

# %%
df2.groupby('구매월').sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24516\3040196912.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2.groupby('구매월').sum()
#         구매시월령(수정)                고객번호      구매금액      결제금액        수량추정     할인율  \
# 구매월
# 201901     4111.0  198670880548942537  22499770  14560410         NaN  359.73
# 201902     9581.0  179490460946424603  21828060  15424972         NaN  240.61
# 201903    20818.0  195440656367623306  18871940  13746002         NaN  241.66
# 201904    13561.0  137091114681422234  15635170  11327772         NaN  173.97
# 201905     7893.0   86817616826343066  12430470   8957479         NaN  113.75
# 201906     5807.0   72886421592442050   9591870   7102447         NaN   85.23
# 201907    10435.0  112459133556049299  12350590   9091753         NaN  143.02
# ...

# %%
df['가입월'] = 0
for i in range(len(df)):
    if str(df['가입일자'][i])[4:6] == '12':
        df['가입월'][i] = '12월'
    elif str(df['가입일자'][i])[4:6] == '01':
        df['가입월'][i] = '01월'
    elif str(df['가입일자'][i])[4:6] == '02':
        df['가입월'][i] = '02월'
    elif str(df['가입일자'][i])[4:6] == '03':
        df['가입월'][i] = '03월'
    elif str(df['가입일자'][i])[4:6] == '04':
        df['가입월'][i] = '04월'
    elif str(df['가입일자'][i])[4:6] == '05':
        df['가입월'][i] = '05월'
    elif str(df['가입일자'][i])[4:6] == '06':
        df['가입월'][i] = '06월'
    elif str(df['가입일자'][i])[4:6] == '07':
        df['가입월'][i] = '07월'
    elif str(df['가입일자'][i])[4:6] == '08':
        df['가입월'][i] = '08월'
    elif str(df['가입일자'][i])[4:6] == '09':
        df['가입월'][i] = '09월'
    elif str(df['가입일자'][i])[4:6] == '10':
        df['가입월'][i] = '10월'
    elif str(df['가입일자'][i])[4:6] == '11':
        df['가입월'][i] = '11월'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24516\1656341653.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['가입월'][i] = '12월'

# %%
df
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 2                  201902282095385  2019-02-28  2019-03-01  2019-03-05
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905092356247  2019-05-10  2019-05-11  2019-05-13
# ...                            ...         ...         ...         ...
# 199512  20200521172454-86563196093  2020-05-22  2020-05-23  2020-05-25
# 199513             201912283245128  2019-12-29  2019-12-30  2020-01-01
# 199514             202004103645638  2020-04-10  2020-04-11  2020-04-13
# 199515             201912283245152  2019-12-29  2019-12-30  2020-01-02
# 199516  20200629224818-99047893650  2020-06-30  2020-07-01  2020-07-04
#
#         구매시월령(수정)             고객번호   구매금액   결제금액    물품대분류  \
# ...

# %%
df.dropna()
df.reset_index(drop=True, inplace= True)

# %%
df['구매월'] = 0
for i in range(len(df)):
    if df['구매일'][i][5:7] == '12':
        df['구매월'][i] = '19년 12월'
    elif df['구매일'][i][2:7] == '19-01':
        df['구매월'][i] = '19년 01월'
    elif df['구매일'][i][2:7] == '19-02':
        df['구매월'][i] = '19년 02월'
    elif df['구매일'][i][2:7] == '19-03':
        df['구매월'][i] = '19년 03월'
    elif df['구매일'][i][2:7] == '19-04':
        df['구매월'][i] = '19년 04월'
    elif df['구매일'][i][2:7] == '19-05':
        df['구매월'][i] = '19년 05월'
    elif df['구매일'][i][2:7] == '19-06':
        df['구매월'][i] = '19년 06월'
    elif df['구매일'][i][2:7] == '19-07':
        df['구매월'][i] = '19년 07월'
    elif df['구매일'][i][2:7] == '19-08':
        df['구매월'][i] = '19년 08월'
    elif df['구매일'][i][5:7] == '09':
        df['구매월'][i] = '19년 09월'
    elif df['구매일'][i][5:7] == '10':
        df['구매월'][i] = '19년 10월'
    elif df['구매일'][i][5:7] == '11':
        df['구매월'][i] = '19년 11월'
    elif df['구매일'][i][5:7] == '01':
        df['구매월'][i] = '20년 01월'
    elif df['구매일'][i][5:7] == '02':
        df['구매월'][i] = '20년 02월'
    elif df['구매일'][i][5:7] == '03':
        df['구매월'][i] = '20년 03월'
    elif df['구매일'][i][5:7] == '04':
        df['구매월'][i] = '20년 04월'
    elif df['구매일'][i][5:7] == '05':
        df['구매월'][i] = '20년 05월'
    elif df['구매일'][i][5:7] == '06':
        df['구매월'][i] = '20년 06월'
    elif df['구매일'][i][5:7] == '07':
        df['구매월'][i] = '20년 07월'
    elif df['구매일'][i][5:7] == '08':
        df['구매월'][i] = '20년 08월'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24776\241799155.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['구매월'][i] = '19년 05월'

# %%
df_sale5 = df[20190129 <= df['가입일자']]
df_sale5 = df_sale5[df_sale5['가입일자'] <=20190201]
df_sale5 = df_sale5.sort_values('구매월')
df_sale5
# Out:
#                              주문번호         구매일       배송시작일       배송완료일  \
# 26491             201901301962890  2019-01-31  2019-02-01  2019-02-03
# 28230             201901311970440  2019-01-31  2019-02-01  2019-02-05
# 26434             201901301963614  2019-01-31  2019-02-01  2019-02-04
# 26433             201901301962745  2019-01-31  2019-02-01  2019-02-03
# 24794             201901291955672  2019-01-30  2019-01-31  2019-02-02
# ...                           ...         ...         ...         ...
# 30981  20200731215113-77362635507  2020-08-01  2020-08-02  2020-08-06
# 31452  20200801193053-51657585565  2020-08-02  2020-08-03  2020-08-05
# 30980  20200731215113-77362635507  2020-08-01  2020-08-02  2020-08-06
# 31027  20200731214127-98648347748  2020-08-01  2020-08-02  2020-08-04
# 32122  20200804230535-57120423764  2020-08-05  2020-08-06  2020-08-08
#
#        구매시월령(수정)             고객번호   구매금액   결제금액    물품대분류  \
# 26491        4.0  201901300780837  12900   7662     수유용품
# ...

# %%
df_sale5.hist(column='물품대분류',by='구매월',bins= 18,figsize=(20,40))
# Out:
# array([[<AxesSubplot: title={'center': '201901'}>,
#         <AxesSubplot: title={'center': '201902'}>,
#         <AxesSubplot: title={'center': '201903'}>,
#         <AxesSubplot: title={'center': '201904'}>],
#        [<AxesSubplot: title={'center': '201905'}>,
#         <AxesSubplot: title={'center': '201906'}>,
#         <AxesSubplot: title={'center': '201907'}>,
#         <AxesSubplot: title={'center': '201908'}>],
#        [<AxesSubplot: title={'center': '201909'}>,
#         <AxesSubplot: title={'center': '201910'}>,
#         <AxesSubplot: title={'center': '201911'}>,
#         <AxesSubplot: title={'center': '201912'}>],
#        [<AxesSubplot: title={'center': '202001'}>,
#         <AxesSubplot: title={'center': '202002'}>,
#         <AxesSubplot: title={'center': '202003'}>,
#         <AxesSubplot: title={'center': '202004'}>],
#        [<AxesSubplot: title={'center': '202005'}>,
#         <AxesSubplot: title={'center': '202006'}>,
# ...

# %%
df_sale2= df_sale2.sort_values('구매월')

# %%
df_sale5.hist('구매월','물품대분류',bins= 8,figsize=(20,40))

plt.savefig('이벤트기간구입자수.png')

# %%
plt.hist(df_sale3['구매월'],bins=18)
# Out:
# (array([1227.,    0.,  157.,    0.,   68.,    0.,   54.,    0.,    0.,
#          158.,    0.,   96.,    0.,  138.,    0.,   76.,    0.,   16.]),
#  array([0.        , 0.44444444, 0.88888889, 1.33333333, 1.77777778,
#         2.22222222, 2.66666667, 3.11111111, 3.55555556, 4.        ,
#         4.44444444, 4.88888889, 5.33333333, 5.77777778, 6.22222222,
#         6.66666667, 7.11111111, 7.55555556, 8.        ]),
#  <BarContainer object of 18 artists>)

# %%
df_sale3= df_sale3.sort_values('구매월')

# %%
df_sale3.hist('구매월','물품대분류',bins= 18,figsize=(20,40))
# Out:
# array([[<AxesSubplot: title={'center': '기저귀'}>,
#         <AxesSubplot: title={'center': '기타'}>,
#         <AxesSubplot: title={'center': '마스크'}>,
#         <AxesSubplot: title={'center': '맘큐'}>],
#        [<AxesSubplot: title={'center': '물티슈'}>,
#         <AxesSubplot: title={'center': '보습제품'}>,
#         <AxesSubplot: title={'center': '생리대'}>,
#         <AxesSubplot: title={'center': '수유용품'}>],
#        [<AxesSubplot: title={'center': '수유제품'}>,
#         <AxesSubplot: title={'center': '아이_생활용품'}>,
#         <AxesSubplot: title={'center': '어른_생활용품'}>,
#         <AxesSubplot: title={'center': '음식'}>],
#        [<AxesSubplot: title={'center': '장난감'}>,
#         <AxesSubplot: title={'center': '주방용품'}>,
#         <AxesSubplot: title={'center': '증정'}>,
#         <AxesSubplot: title={'center': '청결용품'}>],
#        [<AxesSubplot: title={'center': '청결제품'}>,
#         <AxesSubplot: title={'center': '체험팩'}>,
#         <AxesSubplot: title={'center': '화장품'}>,
# ...

# %%
df_sale4= df[df['가입일자'] ==  '20190130']
df_sale4
# Out:
#                   주문번호         구매일       배송시작일       배송완료일  구매시월령(수정)  \
# 25479  201901301957740  2019-01-30  2019-01-31  2019-02-02        4.0
# 25480  201901301957740  2019-01-30  2019-01-31  2019-02-02        4.0
# 25481  201904192297139  2019-04-20  2019-04-21  2019-04-23        7.0
# 25482  201904192297139  2019-04-20  2019-04-21  2019-04-23        7.0
# 25483  201908072701008  2019-08-08  2019-08-09  2019-08-11       11.0
# ...                ...         ...         ...         ...        ...
# 28216  201903312215672  2019-03-31  2019-04-01  2019-04-03        NaN
# 28217  201907302664657  2019-07-30  2019-07-31  2019-08-02        NaN
# 28218  201912183192359  2019-12-19  2019-12-20  2019-12-24        NaN
# 28219  201901311975635  2019-02-01  2019-02-02  2019-02-04        7.0
# 28220  201902061998536  2019-02-07  2019-02-08  2019-02-10        0.0
#
#                   고객번호   구매금액   결제금액 물품대분류  \
# 25479  201901300779655  52100  39070  수유용품
# ...

# %%
plt.hist(df_sale4['구매월'],bins=18)
# Out:
# (array([960.,  97., 112.,  44.,  27., 161., 208., 181.,  60.,  68.,  54.,
#          33., 104., 239., 116.,  73.,  41., 164.]),
#  array([ 0.        ,  1.05555556,  2.11111111,  3.16666667,  4.22222222,
#          5.27777778,  6.33333333,  7.38888889,  8.44444444,  9.5       ,
#         10.55555556, 11.61111111, 12.66666667, 13.72222222, 14.77777778,
#         15.83333333, 16.88888889, 17.94444444, 19.        ]),
#  <BarContainer object of 18 artists>)

# %%
df_sale4= df_sale4.sort_values('구매월')

# %%
df_sale4.hist('구매월','물품대분류',bins= 18,figsize=(20,40))
# Out:
# array([[<AxesSubplot: title={'center': 'SKC'}>,
#         <AxesSubplot: title={'center': '기저귀'}>,
#         <AxesSubplot: title={'center': '마스크'}>,
#         <AxesSubplot: title={'center': '맘큐'}>],
#        [<AxesSubplot: title={'center': '물티슈'}>,
#         <AxesSubplot: title={'center': '보습제품'}>,
#         <AxesSubplot: title={'center': '생리대'}>,
#         <AxesSubplot: title={'center': '수유용품'}>],
#        [<AxesSubplot: title={'center': '수유제품'}>,
#         <AxesSubplot: title={'center': '아이_생활용품'}>,
#         <AxesSubplot: title={'center': '어른_생활용품'}>,
#         <AxesSubplot: title={'center': '음식'}>],
#        [<AxesSubplot: title={'center': '장난감'}>,
#         <AxesSubplot: title={'center': '주방용품'}>,
#         <AxesSubplot: title={'center': '청결용품'}>,
#         <AxesSubplot: title={'center': '청결제품'}>],
#        [<AxesSubplot: title={'center': '체험팩'}>,
#         <AxesSubplot: title={'center': '화장품'}>,
#         <AxesSubplot: title={'center': '휴지'}>, <AxesSubplot: >]],
# ...

# %%
df_sale6 = df[20190130 <= df['가입일자']]
df_sale6 = df_sale6[df_sale6['가입일자'] <=20190201]
df_sale6 = df_sale6.sort_values('구매월')
df_22=df_sale6['구매월'].value_counts()

# %%
df_22
# Out:
# 201901    905
# 201902    766
# 201903    734
# 201904    533
# 201907    465
# 201910    443
# 201912    410
# 201905    335
# 201906    284
# 202002    283
# 202003    256
# 202001    253
# 201909    245
# 201908    228
# 202004    176
# 201911    166
# 202007    156
# 202006    113
# 202005     97
# 202008     22
# Name: 구매월, dtype: int64

# %%
plt.hist(df_sale6[df_sale6['물품대분류']=="수유용품"]["구매월"],label = '수유용품', alpha= 0.5, bins= 17)
plt.xticks(rotation=90)
plt.title('포인트 적립을 위해 가입한 사람들의 수유용품 구매 수')
plt.savefig('포인트 적립을 위해 가입한 사람들의 수유용품 구매 수.png')
