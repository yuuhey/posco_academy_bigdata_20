# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale,minmax_scale,robust_scale
#%matplotlib inline background 그래프 실행 및 결과 확인
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols
from statsmodels.api import qqplot, add_constant
import statsmodels.formula.api as smf
from statsmodels.tools.eval_measures import rmse
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.preprocessing import StandardScaler
#예측
from sklearn.tree import export_graphviz
import graphviz
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
#평가함수
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
#모델 성능 평가
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score,roc_curve,auc,precision_score,recall_score
#confusion matrix
from sklearn.metrics import confusion_matrix, classification_report

from sklearn.metrics import recall_score, f1_score,precision_score,roc_curve,auc

#Scale 변환:평균,표준편차 기준
from sklearn.preprocessing import StandardScaler
#주성분 분석
from sklearn.decomposition import PCA
#회귀분석
import statsmodels.api as sm
#RMSE:root mean squared error 함수
def root_mean_squared_error(y_true,y_pred):
    return np.sqrt(mean_squared_error(y_true,y_pred))
#MAPE:mean absolute percentage error 함수
def mean_absolute_percentage_error(y_true,y_pred):
    return np.mean(np.abs((y_true-y_pred)/y_true))*100
#분류 : KNN
from sklearn.neighbors import KNeighborsClassifier
#로지스틱 회귀
from statsmodels.api import Logit
#데이터 분항
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from IPython.core.display import display, HTML
# 추검정 및 통계 분석 패키지
from scipy import stats
from scipy.stats import shapiro
import scipy.stats
import statsmodels.api as sm
from statsmodels.stats.proportion import proportions_ztest
from sklearn.linear_model import LinearRegression
display(HTML("<style>.container { width:100% !important; }</style>"))

from sklearn.metrics import confusion_matrix, classification_report
from statsmodels.api import Logit

matplotlib.rc('font',family='NanumBarunGothic')
matplotlib.rc('axes', unicode_minus=False)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# 학습데이터 검증데이터 분할 
from sklearn.model_selection import train_test_split

# 파이프라인 
from imblearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# 결측치처리 + 인코딩 / 스케일링 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

# 불균형 데이터 처리
from imblearn.over_sampling import SMOTE

# 학습 
from sklearn.tree import DecisionTreeClassifier

# 교차검증 + 하이퍼 파라미터튜닝 
from sklearn.model_selection import GridSearchCV

# %%
#바꿔야될것
df_raw = pd.read_csv('/home/piai/다운로드/쿠킹_밥추출(파생변수포함).csv')
df_raw
# Out:
#        순번 생산라인코드                                  품목명_x_x 작업장코드_x    충전실온도_x  \
# 0       8   C088                            프리가베이스밥1kg(재)    W003  72.273407
# 1      10   C088                               CJ낙지볶음밥(재)    W003  73.768633
# 2      15   C088                          통새우볶음밥(노브랜드)(재)    W003  71.660051
# 3       9   D087                            비비고불고기비빔밥200g    W005  71.226196
# 4      12   D088                              CJ낙지볶음밥*5ea    W005  72.245427
# ...    ..    ...                                      ...     ...        ...
# 10156   3   D087  (1)Homeplus signature 날치알이톡톡터지는날치알밥(알밥)    W005  71.288798
# 10157   7   D087  (1)Homeplus signature 날치알이톡톡터지는날치알밥(알밥)    W005  70.610616
# 10158   9   D088                             (쿠팡)곰곰갈비맛치킨밥    W005  69.732381
# 10159  10   D088                           무명식당뿌리채소영양밥3kg    W005  71.459932
# 10160   4   D088                                 콩콩푸드밥3kg    W005  70.664452
#
#            쿠킹온도_x  쿠킹스팀압력_x   실링압력_x  불량여부
# 0      158.156207    24.255  214.474     0
# 1      153.123283    23.903  211.394     0
# 2      140.555351    23.464  207.693     0
# 3      126.899896    23.316  203.637     0
# 4      137.014077    23.312  204.304     0
# ...           ...       ...      ...   ...
# 10156  138.091898    23.602  206.561     0
# 10157  138.257466    23.031  199.343     1
# 10158  133.916831    23.656  213.413     0
# 10159  143.598182    24.026  215.243     0
# 10160  100.773102    23.339  209.513     0
#
# [10161 rows x 9 columns]

# %%
#바꿔야될것
Y = df_raw['불량여부'].astype(str)
X = df_raw[['충전실온도_x','쿠킹온도_x','쿠킹스팀압력_x','생산라인코드']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y , random_state=2000)

# %%
# 문자 / 숫자 파이프 구성 
numeric_pipe = make_pipeline( SimpleImputer() , MinMaxScaler() )
category_pipe = make_pipeline( SimpleImputer(strategy='most_frequent') , OneHotEncoder())

# %%
# 숫자와 문자를 구분하는 리스트
numeric_list = X.describe().columns.tolist()
category_list = X.describe(include='object').columns.tolist()

# %%
preprocess_pipe = make_column_transformer( (numeric_pipe, numeric_list),
                                           (category_pipe, category_list))
model_pipe = make_pipeline(preprocess_pipe, SMOTE(),DecisionTreeClassifier())

# %%
model_pipe.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['충전실온도_x', '쿠킹온도_x',
#                                                    '쿠킹스팀압력_x']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['생산라인코드'])])),
#                 ('smote', SMOTE()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
#파라메터 바꾸기
grid_model = GridSearchCV(model_pipe , param_grid={} , cv=3 , n_jobs='f1')
grid_model.fit(X_train,Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_650/3083072665.py in <module>
#       1 #파라메터 바꾸기
#       2 grid_model = GridSearchCV(model_pipe , param_grid={} , cv=3 , n_jobs='f1')
# ----> 3 grid_model.fit(X_train,Y)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     781             refit_metric = self.refit
#     782
# --> 783         X, y, groups = indexable(X, y, groups)
#     784         fit_params = _check_fit_params(X, fit_params)
#     785
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     431
#     432     result = [_make_indexable(X) for X in iterables]
# --> 433     check_consistent_length(*result)
#     434     return result
#     435
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     385     uniques = np.unique(lengths)
#     386     if len(uniques) > 1:
# --> 387         raise ValueError(
#     388             "Found input variables with inconsistent numbers of samples: %r"
#     389             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [7620, 10161]

# %%
best_model = grid_model.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_650/1125654245.py in <module>
# ----> 1 best_model = grid_model.best_estimator_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
import pickle

# %%
#모델 저장 
pickle.dump(best_model, open('model.sav','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_650/3834856252.py in <module>
#       1 #모델 저장
# ----> 2 pickle.dump(best_model, open('model.sav','wb'))
#
# NameError: name 'best_model' is not defined

# %%
# 모델 불러오기 
pickle.load( open('model.sav','rb'))
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['충전실온도_x', '쿠킹온도_x',
#                                                    '쿠킹스팀압력_x']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['생산라인코드'])])),
#                 ('smote', SMOTE()),
#                 ('decisiontreeclassifier', DecisionTreeClassifier())])
