# %%
execfile('setting.py')

# %% [markdown]
# # 파일 불러오기

# %%
a = pd.read_csv('/Users/bagdaemin/Desktop/eoals/Computer/python/posco/빅데이터/보험프로젝트/01_Data_set_대출.csv')
b = pd.read_csv('/Users/bagdaemin/Desktop/eoals/Computer/python/posco/빅데이터/보험프로젝트/02_Data_set_보험_정제3.csv', encoding='euc-kr')

# %% [markdown]
# # 보험 정리

# %%
c = b.groupby(['OCCP_NAME_G'],as_index=False)['CUST_JOB_INCM'].agg('mean')

# %%
c
# Out:
#    OCCP_NAME_G
# 0     1차산업 종사자
# 1     2차산업 종사자
# 2     3차산업 종사자
# 3      고소득 전문직
# 4          공무원
# 5     기업/단체 임원
# 6           기타
# 7       단순 노무직
# 8       단순 사무직
# 9          사무직
# 10    예체능계 종사자
# 11         운전직
# 12         자영업
# 13         전문직
# 14          주부
# 15          학생

# %%
plt.figure(figsize=(30,10))
plt.bar(c['OCCP_NAME_G'],c['CUST_JOB_INCM'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CUST_JOB_INCM'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ## 상관관계 확인

# %% [markdown]
# ### 최초신용등급 vs 최근신용등급

# %%
plt.scatter(b['STRT_CRDT_GRAD'], b['LTST_CRDT_GRAD'])

# %% [markdown]
# ### 실효해지건수 vs 최근1년 실효해지건수

# %%
plt.scatter(b['CNTT_LAMT_CNT'], b['LT1Y_CTLT_CNT'])

# %% [markdown]
# ### 보험료 연체율 vs 최근1년 이내 보험료 연체율

# %%
plt.scatter(b['PREM_OVDU_RATE'], b['LT1Y_PEOD_RATE'])

# %% [markdown]
# ### 최근1년 보험료연체율  vs 최근1년 약대 연체율

# %%
plt.scatter(b['CNTT_LAMT_CNT'], b['LT1Y_PEOD_RATE'])

# %%
def cancel_cat(cancel):
    if (cancel > 1):
        return 1
    else:
        return 0


cancel = b['CNTT_LAMT_CNT'].apply(cancel_cat)

# %%
plt.scatter(cancel, b['LT1Y_PEOD_RATE'])

# %%
plt.scatter(cancel, b['CUST_JOB_INCM'])
